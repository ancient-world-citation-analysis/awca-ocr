# %% [markdown]
# # TesseractManagerTests

# %%
# The capture command is used here to minimize visual clutter.
# %%capture
# !sudo apt-get install tesseract-ocr-all
# !pip3 install pytesseract
# !pip install langdetect
# !pip install pdf2image
# !apt-get install poppler-utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AWCA/Colab_notebooks/OCR/pDonovan/awca-ocr/
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1W2EROe2FItlaK99U-WY_qaBOc2UD_LI0/AWCA/Colab_notebooks/OCR/pDonovan/awca-ocr
#  CorrectnessCheck.ipynb		    OCRDemo2.ipynb
#  correctness_check_results.pickle   __pycache__
#  DatasetMake.ipynb		    temp
# 'large_sample(1).pdf'		    tesseract_manager.py
#  large_sample.pdf		    TesseractManagerTests.ipynb

# %%
from tesseract_manager import Text

# %%
test_text = Text('temp/BERT.pdf', './bert_out', verbose=True)
test_text.save_ocr()
# Out:
# 0 out of 16 pages analyzed in 0.00 seconds...
# 1 out of 16 pages analyzed in 13.99 seconds...
# 2 out of 16 pages analyzed in 28.02 seconds...
# 3 out of 16 pages analyzed in 39.31 seconds...
# 4 out of 16 pages analyzed in 54.24 seconds...
# 5 out of 16 pages analyzed in 66.78 seconds...
# 6 out of 16 pages analyzed in 81.17 seconds...
# 7 out of 16 pages analyzed in 93.64 seconds...
# 8 out of 16 pages analyzed in 108.30 seconds...
# 9 out of 16 pages analyzed in 121.22 seconds...
# 10 out of 16 pages analyzed in 136.22 seconds...
# 11 out of 16 pages analyzed in 152.16 seconds...
# 12 out of 16 pages analyzed in 164.84 seconds...
# 13 out of 16 pages analyzed in 175.81 seconds...
# 14 out of 16 pages analyzed in 188.34 seconds...
# 15 out of 16 pages analyzed in 195.21 seconds...
